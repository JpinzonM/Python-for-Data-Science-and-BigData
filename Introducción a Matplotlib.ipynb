# %% [markdown]
# <h1 align="center">
# Introducción a Matplotlib.
# </h1>

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#load Data
df = pd.read_csv('C:/Users/jorge/Desktop/Linkedin DATASCIENCE/CURSO/data/2008.csv', nrows=100000)

# %%
data = np.unique(df.Cancelled, return_counts=True)
data
# Out:
# (array([0, 1], dtype=int64), array([98858,  1142], dtype=int64))

# %%
#Creación de un Grafico de Pie.
plt.pie(x = data[1],
        labels = data[0],
        colors = ["Black", "blue"],
        shadow = True,
       startangle=90,
       radius=1.5)
plt.show()

# %%
# Modificar graficos: 
#load Data 1.M
np.random.seed(0)
df = pd.read_csv('C:/Users/jorge/Desktop/Linkedin DATASCIENCE/CURSO/data/2008.csv', nrows=1000000)
df = df.sample(frac=1).head(100)

# %%
#Grafico de Burbujas
plt.scatter(x=df.DayofMonth, y = df.ArrDelay, s=df.Distance)

# %%
#alpha permite cambiar la intensidad del color
plt.scatter(x=df.DayofMonth, y = df.ArrDelay, s=df.Distance, alpha= .3)

# %%
#c es un filtro de color aplicado a los dias de la semana, morados dias de la semana y amarillos correspondientes 
#a los fines de semana.
plt.scatter(x=df.DayofMonth, y = df.ArrDelay, s=df.Distance, alpha= .3, c=df.DayOfWeek.isin([6 , 7]))

# %%
#agregar titulos
plt.scatter(x=df.DayofMonth, y = df.ArrDelay, s=df.Distance, alpha= .3, c=df.DayOfWeek.isin([6 , 7]))
plt.title("Retrasos en EEUU")
plt.xlabel("Día del Mes")
plt.ylabel("Retraso al llegar")
# Out:
# Text(0, 0.5, 'Retraso al llegar')

# %%
#LIMITE EN LA ESCALA VERTICAL
plt.scatter(x=df.DayofMonth, y = df.ArrDelay, s=df.Distance, alpha= .3, c=df.DayOfWeek.isin([6 , 7]))
plt.title("Retrasos en EEUU")
plt.xlabel("Día del Mes")
plt.ylabel("Retraso al llegar")
plt.ylim([0,150])
# Out:
# (0.0, 150.0)

# %%
#Cambiar el numero de marcas en el eje x.
plt.scatter(x=df.DayofMonth, y = df.ArrDelay, s=df.Distance, alpha= .3, c=df.DayOfWeek.isin([6 , 7]))
plt.title("Retrasos en EEUU")
plt.xlabel("Día del Mes")
plt.ylabel("Retraso al llegar")
plt.ylim([0,150])
plt.xticks([0,15,30])
# Out:
# ([<matplotlib.axis.XTick at 0x1fc897dfc40>,
#   <matplotlib.axis.XTick at 0x1fc897dfc10>,
#   <matplotlib.axis.XTick at 0x1fc897d77f0>],
#  [Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, '')])

# %%
#Añadir texto
plt.scatter(x=df.DayofMonth, y = df.ArrDelay, s=df.Distance, alpha= .3, c=df.DayOfWeek.isin([6 , 7]))
plt.title("Retrasos en EEUU")
plt.xlabel("Día del Mes")
plt.ylabel("Retraso al llegar")
plt.ylim([0,150])
plt.xticks([0,15,30])
plt.text(x=28, y=120, s="Mi vuelo")
# Out:
# Text(28, 120, 'Mi vuelo')

# %%
#Etiquetas y Leyendas en Matplotlib.

# %%
#load Data
df = pd.read_csv('C:/Users/jorge/Desktop/Linkedin DATASCIENCE/CURSO/data/2008.csv', nrows=100000)
data = np.unique(df.DayOfWeek, return_counts=True)
labs = ["Lun", "Mar", "Mie", "Jue", "Vie", "Sab", "Dom"]
data
# Out:
# (array([1, 2, 3, 4, 5, 6, 7], dtype=int64),
#  array([14519, 14710, 14694, 17079, 14517, 11285, 13196], dtype=int64))

# %%
plt.pie(x = data[1],
        labels= data[0],
        radius=1.5,
        colors=["Red", "Green", "Orange", "Blue", "Gray", "Pink", "Black"],
        startangle=90)
plt.show()

# %%
#Modificar etiquetas de los triangulos
plt.pie(x = data[1],
        labels= labs,
        radius=1.5,
        colors=["Red", "Green", "Orange", "Blue", "Gray", "Pink", "Black"],
        startangle=90)
plt.show()

# %%
#cambiar secuencia de colores por una predefinida
#del paquete seaborn.
plt.pie(x = data[1],
        labels= labs,
        radius=1.5,
        colors=sns.color_palette("hls",7),
        startangle=90)
plt.show()

# %%
#extrae los diagramas de sectores
plt.pie(x = data[1],
        labels= labs,
        radius=1.5,
        colors=sns.color_palette("hls",7),
        explode = (0,0,.2,0,0,0,0.1),
        startangle=90)
plt.show()

# %%
#poner los porcentajes de cada sector. 
plt.pie(x = data[1],
        labels= labs,
        radius=1.5,
        colors=sns.color_palette("hls",7),
        explode = (0,0,.2,0,0,0,0.1),
        startangle=90,
       autopct = "%1.1f%%")
plt.show()

# %%
#label distance
plt.pie(x = data[1],
        labels= labs,
        radius=1.5,
        colors=sns.color_palette("hls",7),
        explode = (0,0,.2,0,0,0,0.1),
        startangle=90,
       autopct = "%1.1f%%",
       labeldistance=1.5)
plt.show()

# %%
#añadir una legenda
plt.pie(x = data[1],
        #labels= labs,
        radius=.7,
        colors=sns.color_palette("hls",7),
        explode = (0,0,.2,0,0,0,0.1),
        startangle=90,
       autopct = "%1.1f%%")
plt.legend(loc="upper right", labels = labs)
plt.show()

# %%
plt = sns.barplot(x= labs, y = data[1])
plt.set(xlabel = "Día de la semana", ylabel="Número de vuelos")
# Out:
# [Text(0.5, 0, 'Día de la semana'), Text(0, 0.5, 'Número de vuelos')]
